# %% [markdown]
# # Diefferent audio format
# - wav, mp3, acc, aiff

# %%
import numpy as np
import soundfile as sf
from glob import glob
from matplotlib import pyplot as plt
import os

import IPython.display

# %%
files
# Out:
# ['../sample_audio/farend_Diaz1.wav',
#  '../sample_audio/farend_Diaz1.m4a',
#  '../sample_audio/farend_Diaz1.aif',
#  '../sample_audio/farend_Diaz1.mp3']

# %%
file_wav = '../sample_audio/farend_Diaz1.wav'
file_m4a = '../sample_audio/farend_Diaz1.m4a'
file_aif = '../sample_audio/farend_Diaz1.aif'
file_mp3 = '../sample_audio/farend_Diaz1.mp3'

# %%
def plot(wav_data, freq):
    assert len(wav_data.shape) == 1
    plt.figure(0, figsize=(6, 4))
    plt.plot(wav_data)
    plt.grid()
    
    interval = 10
    length_sec = int(len(wav_data)/freq) + 1
    interval = min(10, length_sec)
    ind_1 = np.arange(0, length_sec+1, int(length_sec/interval))
    ind_2 = ind_1 * freq
    plt.xticks(ind_2, ind_1)
    plt.xlim([0, len(wav_data)])
    plt.xlabel("Time (sec.): total %0.2f" % (len(wav_data)/freq))
    plt.ylabel("Amplitude")
    plt.show()

# %% [markdown]
# ## wav

# %%
IPython.display.Audio(file_wav)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, freq = sf.read(file_wav)
plot(data, freq)
file_wav_write = file_wav.replace('.wav', '_write.wav')
sf.write(file_wav_write, data, freq, 'PCM_24')
IPython.display.Audio(file_wav_write)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## MP3

# %%
IPython.display.Audio(file_mp3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, freq = sf.read(file_mp3)
plot(data, freq)
# file_wav_write = file_mp3.replace('.mp3', '_write.mp3')
# sf.write(file_wav_write, data, freq, 'PCM_24')
# IPython.display.Audio(file_wav_write)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-0e58376fb303> in <module>
# ----> 1 data, freq = sf.read(file_mp3)
#       2 plot(data, freq)
#       3 # file_wav_write = file_mp3.replace('.mp3', '_write.mp3')
#       4 # sf.write(file_wav_write, data, freq, 'PCM_24')
#       5 # IPython.display.Audio(file_wav_write)
#
# ~/pyenv/random/lib/python3.6/site-packages/soundfile.py in read(file, frames, start, stop, dtype, always_2d, fill_value, out, samplerate, channels, format, subtype, endian, closefd)
#     255     """
#     256     with SoundFile(file, 'r', samplerate, channels,
# --> 257                    subtype, endian, format, closefd) as f:
#     258         frames = f._prepare_read(start, stop, frames)
#     259         data = f.read(frames, dtype, always_2d, fill_value, out)
#
# ...
