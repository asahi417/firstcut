# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, freqz
import librosa
from pydub import AudioSegment

# %%
import ssnmf

# %%
# input
# y_n: Noise Signal
# y_o: Original Signal
y, sr = librosa.load('..\..\sample_files\sample_5.wav')
y_n = y[0:sr * 4]
y_o = y

# %%
y_out = ssnmf.SSNMF(y_o, y_n)

# %%
plt.plot(y_o)
plt.plot(y_out)

# %%
librosa.output.write_wav("out.wav", y_out, sr)
